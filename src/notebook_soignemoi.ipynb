# %%
import os
import django
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "SoigneMoi.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from soignemoiwebsite.models import Medecin, Specialite

# %%
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
m = Medecin.objects.get(pk=3)

# %%
m
# Out:
# <Medecin: Dr Brokovitch Erin, spécialité : Cardiologie>

# %%
m.nom
# Out:
# 'Brokovitch'

# %%
liste_sejours = m.sejour_set.all()

# %%
for s in liste_sejours:
    print(s.user.email)
# Out:
# fifi@esteljo.com
# fifi@esteljo.com

# %%
patients = [sejour.user for sejour in m.sejour_set.all()]

# %%
patients
# Out:
# [<Patient:  Mr Cardot Philippe>, <Patient:  Mr Cardot Philippe>]

# %%
m = Medecin.objects.filter(nom='Wagner')

# %%
m
# Out:
# <QuerySet [<Medecin: Dr Wagner Melinda, spécialité : Cardiologie>]>

# %%
patients = [sejour.user for sejour in m.sejour_set.all()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 patients = [sejour.user for sejour in m.sejour_set.all()]
#
# AttributeError: 'QuerySet' object has no attribute 'sejour_set'

# %%
liste_sejours = m.sejour_set.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 liste_sejours = m.sejour_set.all()
#
# AttributeError: 'QuerySet' object has no attribute 'sejour_set'

# %%
from django.contrib.auth import authenticate

# %%
jd = authenticate(email='jd@duj.com', password='buffertoto')

# %%
jd
# Out:
# <CustomUser: jd@duj.com>

# %%
bool(jd)
# Out:
# True

# %%
jd = Medecin.objects.filter(nom='Dujardin')

# %%
jd
# Out:
# <QuerySet [<Medecin: Dr Dujardin Jean, spécialité : Rhumatologie>]>

# %%
jd.matricule_medecin
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 jd.matricule_medecin
#
# AttributeError: 'QuerySet' object has no attribute 'matricule_medecin'

# %%
Medecin.objects.create(
        email="jeanmev@tahiti.com",
        genre="Mr",
        nom="Mevlud",
        prenom="Jean",
        matricule_medecin="M1234567890",
        specialite="Psychiatrie"
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Medecin.objects.create(
#       2         email="jeanmev@tahiti.com",
#       3         genre="Mr",
#       4         nom="Mevlud",
#       5         prenom="Jean",
#       6         matricule_medecin="M1234567890",
#       7         specialite="Psychiatrie"
#       8     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/django/db/models/manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/django/db/models/query.py:656, in QuerySet.create(self, **kwargs)
#     651 def create(self, **kwargs):
#     652     """
#     653     Create a new object with the given kwargs, saving it to the database
#     654     and returning the created object.
#     655     """
# --> 656     obj = self.model(**kwargs)
#     657     self._for_write = True
#     658     obj.save(force_insert=True, using=self.db)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/django/db/models/base.py:543, in Model.__init__(self, *args, **kwargs)
#     537 if is_related_object:
#     538     # If we are passed a related instance, set it using the
#     539     # field.name instead of field.attname (e.g. "user" instead of
#     540     # "user_id") so that the object gets properly cached (and type
#     541     # checked) by the RelatedObjectDescriptor.
#     542     if rel_obj is not _DEFERRED:
# --> 543         _setattr(self, field.name, rel_obj)
#     544 else:
#     545     if val is not _DEFERRED:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/django/db/models/fields/related_descriptors.py:266, in ForwardManyToOneDescriptor.__set__(self, instance, value)
#     262 # An object must be an instance of the related class.
#     263 if value is not None and not isinstance(
#     264     value, self.field.remote_field.model._meta.concrete_model
#     265 ):
# --> 266     raise ValueError(
#     267         'Cannot assign "%r": "%s.%s" must be a "%s" instance.'
#     268         % (
#     269             value,
#     270             instance._meta.object_name,
#     271             self.field.name,
#     272             self.field.remote_field.model._meta.object_name,
#     273         )
#     274     )
#     275 elif value is not None:
#     276     if instance._state.db is None:
#
# ValueError: Cannot assign "'Psychiatrie'": "Medecin.specialite" must be a "Specialite" instance.

# %%
spe = Specialite.objects.get(nom="Psychiatrie")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 spe = Specialite.objects.get(nom="Psychiatrie")
#
# NameError: name 'Specialite' is not defined

# %%
spe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 spe
#
# NameError: name 'spe' is not defined

# %%
from soignemoiwebsite.models import Specialite, Medecin

# %%
spe = Specialite.objects.get(nom="Psychiatrie")

# %%
spe
# Out:
# <Specialite: Psychiatrie>

# %%
Medecin.objects.create(
        email="jeanmev@tahiti.com",
        genre="Mr",
        nom="Mevlud",
        prenom="Jean",
        matricule_medecin="M1234567890",
        specialite=spe
    )
# Out:
# <Medecin: Dr Mevlud Jean, spécialité : Psychiatrie>

# %%
jm = Medecin.objects.filter(nom='Mevlud')

# %%
jm.password = 'mevlut'

# %%
jm.password
# Out:
# 'mevlut'

# %%
from accounts.models import CustomUser

for user in CustomUser.objects.all():
    if not user.password.startswith('pbkdf2_'):  # Vérifie si le mot de passe est haché
        user.set_password(user.password)
        user.save()

# %%
jd = Medecin.objects.get(pk=2)

# %%
jd.is_active
# Out:
# True

# %%
jd
# Out:
# <Medecin: Dr Dujardin Jean, spécialité : Rhumatologie>

# %%
jd.is_admin
# Out:
# False

# %%
jd = authenticate(email='jd@duj.com', password='buffertoto')

# %%
jd
# Out:
# <CustomUser: jd@duj.com>

# %%
bool(jd)
# Out:
# True

# %%
jd = Medecin.objects.get(pk=2)

# %%
jd.is_active
# Out:
# True

# %%
hasattr(jd, 'matricule_medecin')
# Out:
# True

# %%
jd.matricule_medecin
# Out:
# 'jd123456'

# %%
jd.is_authenticated
# Out:
# True
